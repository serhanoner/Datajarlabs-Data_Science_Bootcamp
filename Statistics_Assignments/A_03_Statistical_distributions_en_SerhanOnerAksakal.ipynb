# %% [markdown]
# **(1)** By using distribution=np.random.name_distribution([],[]), write the name of distribution of your choice in place of `name_distribution`and fill out the bracket with your choice again. Then please,
#
# **(a)** Draw the histogram and interpret

# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt

epsilon = 0
delta = 1
n = 1000

plt.figure(figsize=(8,5))
std_normal_distribution=np.random.normal(epsilon,delta,n)
plt.hist(normal_distribution, bins = 100)
plt.show()

# %% [markdown]
# **(b)** Draw Q-Q plot and interpret

# %%
normal_distribution = np.random.normal(50,300,n)
normal_distribution.sort()
std_normal_distribution.sort()

plt.figure(figsize=(8,5), dpi = 100)

plt.plot(std_normal_distribution, normal_distribution, "o")
plt.title("Q-Q Plot")
plt.xlabel('Standard Normal Distribution') 
plt.ylabel('Normal Distribution')

plt.show()

# %% [markdown]
# **(2)** Get the google stock quotes from 2015-2017 using https://finance.yahoo.com/. Using this data, calculate the stock return with the following formula:
#
# $$P_t-P_{t-1}/P_{t-1}$$
#
# where $P_t$ represents the stock price at time t and $P_{t-1}$ denotes the stock price at time t-1. What do you think about the return distribution?
#
# **Note:** Data is retrieved from https://finance.yahoo.com/ as follows. After clicking the given address, type the name of the stock you want to search in the search section (eg google). Click on the search result below to go to the relevant stock. When you get to the page with the relevant stock information, click the Historical Prices tab, select the relevant date range, then click Apply. Finally, click the Download Data button to download the data. Alternative you can use `yfinance` library

# %%
df = pd.read_csv('GOOG.csv')
df
# Out:
#           Date         Open         High  ...        Close    Adj Close   Volume
# 0   2021-08-16  2760.000000  2779.810059  ...  2778.320068  2778.320068   902000
# 1   2021-08-17  2763.820068  2774.370117  ...  2746.010010  2746.010010  1063600
# 2   2021-08-18  2742.310059  2765.879883  ...  2731.399902  2731.399902   746700
# 3   2021-08-19  2709.350098  2749.040039  ...  2738.270020  2738.270020   914800
# 4   2021-08-20  2741.659912  2772.290039  ...  2768.739990  2768.739990   778200
# ..         ...          ...          ...  ...          ...          ...      ...
# 60  2021-11-09  2994.919922  3007.570068  ...  2984.969971  2984.969971   843800
# 61  2021-11-10  2960.195068  2974.000000  ...  2932.520020  2932.520020  1135400
# 62  2021-11-11  2942.139893  2970.044922  ...  2934.959961  2934.959961   623200
# 63  2021-11-12  2956.629883  2997.189941  ...  2992.909912  2992.909912   852000
# 64  2021-11-15  3000.000000  3009.540039  ...  2987.760010  2987.760010   811400
#
# [65 rows x 7 columns]

# %%
dataset123 = []

for i in range(1,65):
  stock_return = ((df['Close'][i]) - (df['Close'][i-1])) / (df['Close'][i-1])
  dataset123.append(stock_return)

len(dataset123)
# Out:
# 64

# %%
dataset123.sort()

normally_distributed_dataset123 = np.random.normal(np.mean(dataset123),
                                         np.std(dataset123), 64)
normally_distributed_dataset123.sort()
normally_distributed_dataset123
# Out:
# array([-0.02984891, -0.0278038 , -0.02442314, -0.0185506 , -0.01829269,
#        -0.01783704, -0.01780066, -0.01779602, -0.01608333, -0.01476051,
#        -0.01451272, -0.01337187, -0.01306128, -0.01211843, -0.01189886,
#        -0.01138427, -0.00964941, -0.00956291, -0.00909972, -0.00903454,
#        -0.0081045 , -0.00806652, -0.00782781, -0.00722511, -0.00628166,
#        -0.00617181, -0.006052  , -0.00507919, -0.00506861, -0.00438763,
#        -0.0032987 , -0.00235605, -0.00231293, -0.00180328, -0.00098452,
#         0.00011098,  0.00049516,  0.0013522 ,  0.00145888,  0.00232225,
#         0.00268391,  0.00347415,  0.00385408,  0.00413295,  0.00419263,
#         0.00454062,  0.00505614,  0.00716803,  0.00743829,  0.00782434,
#         0.00860997,  0.01289664,  0.01340508,  0.01344448,  0.01692844,
#         0.01700797,  0.01755871,  0.01855848,  0.01898069,  0.01951561,
#         0.02195539,  0.02305129,  0.02688697,  0.03569369])

# %%
plt.figure(figsize=(8,5), dpi = 150)
title_font = {'family': 'arial', 'color': 'darkred','weight': 'bold','size': 13 }
axis_font  = {'family': 'arial', 'color': 'darkblue','weight': 'bold','size': 10 }
plt.title('Sample Data & Normally Distributed Data', fontdict = title_font)
plt.xlabel('Sample Data', fontdict = axis_font)
plt.ylabel('Normally Distributed Data', fontdict = axis_font)
plt.scatter(normally_distributed_dataset123, dataset123)
plt.plot([np.min(normally_distributed_dataset123), np.max(normally_distributed_dataset123)],
         [np.min(dataset123), np.max(dataset123)], c='red')
plt.show()

# %% [markdown]
# It seems to me that the data does not have that much outliers, thus the change in the stock prices in consecutive days is not that high.
# Actually, they are pretty small.
