# %%
#Question 1

# %% [markdown]
# # It is a regression problem since it is not a categorical value, it is a continuous value. Hence, we're trying to quantify it.

# %%
#Question2

# %% [markdown]
# 1.   That's true. OLS is a special type of optimization algorithm for Linear Regression.
# 2.   Right now, I lack the knowledge to answer that. Hopefully, in the upcoming lectures, I'll have a chance to answer that.
# 3.  They're not. Prediction is about the test-values, whereas estimation is a different kind of subject.
# 4. True.

# %%
#Question3

# %% [markdown]
# **I guess it'd be the special offers like get 3/pay for 2, and the numbers would increase as 10/7, 15,10.. etc. It wouldn't be a fully free special offer but it would probably increase the number of sales.**
