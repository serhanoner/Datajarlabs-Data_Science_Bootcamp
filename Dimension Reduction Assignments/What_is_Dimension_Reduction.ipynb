# %% [markdown]
# *   They can still retain their tails and their ears on their shadows on the wall. Also their body and leg shapes can be separated, if the angle is configured for one to be able to see it.
# *   However, if there is a body-move that make them look similar in 3-d real life, their shadows can get inseparable from each other. That includes, their body shape, their ears, their legs, and even their tails.
