# %% [markdown]
# Given the size of the house, estimating the price of it, is a regression problem
#
# From the clothes of those who come to see the house, to conclude who has a high or low probability of buying the house, is a classification problem.
#
# Using parameters such as location and date, calculate the probability of rain, is a classification problem.
#
# Estimating a one's salary using parameters such as education and experience, is a regression problem.
#
# Estimation one's age, classification, if its for a age group, I suppose.
#
# Estimation one's income, is a regression problem.
#
# Estimate the direction of price of any stock is a classification problem.

# %%
#I'm a bit sleepy, so it'd be good to know the answers if I'm mistaken. Thanks in advance!
