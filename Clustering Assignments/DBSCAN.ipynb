# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import datasets, metrics
from sklearn.cluster import DBSCAN

# %%
heart_disease = pd.read_excel('Processed_Cleveland.xlsx')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal num
# 0     63    1   1       145   233    1  ...      0      2.3      3   0     6   0
# 1     67    1   4       160   286    0  ...      1      1.5      2   3     3   2
# 2     67    1   4       120   229    0  ...      1      2.6      2   2     7   1
# 3     37    1   3       130   250    0  ...      0      3.5      3   0     3   0
# 4     41    0   2       130   204    0  ...      0      1.4      1   0     3   0
# ..   ...  ...  ..       ...   ...  ...  ...    ...      ...    ...  ..   ...  ..
# 298   45    1   1       110   264    0  ...      0      1.2      2   0     7   1
# 299   68    1   4       144   193    1  ...      0      3.4      2   2     7   2
# 300   57    1   4       130   131    0  ...      1      1.2      2   1     7   3
# 301   57    0   2       130   236    0  ...      0      0.0      2   1     3   1
# 302   38    1   3       138   175    0  ...      0      0.0      1   ?     3   0
#
# [303 rows x 14 columns]

# %%
# Define the features and the outcome
X = heart_disease.iloc[:, :13]
y = heart_disease.iloc[:, 13]

# Replace missing values (marked by ?) with a 0
X = X.replace(to_replace='?', value=0)

# Binarize y so that 1 means heart disease diagnosis and 0 means no diagnosis
y = np.where(y > 0, 0, 1)

# %%
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %% [markdown]
# Below I tried to visualize different values of epsilons and min points.

# %%
for i in np.arange(0.25, 2.75, 0.25):
  for j in range (3,13):

    print(f"DBSCAN with eps: {i}, and min Points: {j}")

    dbscan_cluster = DBSCAN(eps=i, min_samples=j)

    clusters = dbscan_cluster.fit_predict(X_std)

    pca = PCA(n_components=2).fit_transform(X_std)

    plt.figure(figsize=(10,5))
    colours = 'rbg'
    for i in range(pca.shape[0]):
        plt.text(pca[i, 0], pca[i, 1], str(clusters[i]),
                color=colours[y[i]],
                fontdict={'weight': 'bold', 'size': 50}
            )

    plt.xticks([])
    plt.yticks([])
    plt.axis('off')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Separating two sets is really difficult with this approach.

# %%
# DBSCAN with eps=1 fixed
for j in range(1,10):

  print(f"DBSCAN with eps: 1, and min Points: {j}")
  dbscan_cluster = DBSCAN(eps=1, min_samples=j, metric='euclidean')

  clusters = dbscan_cluster.fit_predict(X_std)

  print("DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): {}"
      .format(metrics.adjusted_rand_score(y, clusters)))
# Out:
# DBSCAN with eps: 1, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0004340648309851829
# DBSCAN with eps: 1, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.008961679875102968
# DBSCAN with eps: 1, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.002755933782262106
# DBSCAN with eps: 1, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0

# %% [markdown]
# There isn't any even positive ARI score for these DBSCAN approaches, nearly.
# But we got our best result when
# DBSCAN with eps: 3.0, and min Points: 3
# And its ARI score is: 0.02064668894650054

# %%
#silhouette score for the best eps and minsamples

dbscan_cluster = DBSCAN(eps=1, min_samples=1, metric='euclidean')
clusters = dbscan_cluster.fit_predict(X_std)

print("DBSCAN çözümünün siluet skoru: {}"
      .format(metrics.silhouette_score(X_std, clusters, metric='euclidean')))
# Out:
# DBSCAN çözümünün siluet skoru: 0.02806263640143188

# %% [markdown]
# Its incredibly bad.

# %%
# DBSCAN with min_samples=1

for i in np.arange(0.5, 5, 0.25):
  print(f"DBSCAN with eps: {i}, and min Points: 1")
  
  dbscan_cluster = DBSCAN(eps=i, min_samples=1, metric='euclidean')

  clusters = dbscan_cluster.fit_predict(X_std)

  print("DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): {}"
      .format(metrics.adjusted_rand_score(y, clusters)))
# Out:
# DBSCAN with eps: 0.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 8.68128597420814e-05
# DBSCAN with eps: 0.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00013021930957340477
# DBSCAN with eps: 1.0, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0004340648309851829
# DBSCAN with eps: 1.25, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0034691953611277575
# DBSCAN with eps: 1.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.007935993562794265
# DBSCAN with eps: 1.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01368836573290993
# DBSCAN with eps: 2.0, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.021441604491943305
# DBSCAN with eps: 2.25, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.08072698143984362
# DBSCAN with eps: 2.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.02761084266040348
# DBSCAN with eps: 2.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.020851684467945303
# DBSCAN with eps: 3.0, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01717734452910878
# DBSCAN with eps: 3.25, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.011812870097277906
# DBSCAN with eps: 3.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.012693232823408757
# DBSCAN with eps: 3.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.005276346222230343
# DBSCAN with eps: 4.0, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0001369364398033298
# DBSCAN with eps: 4.25, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0

# %%
#just wanted to see the best option interval that I had use.

for i in np.arange(0.5, 5, 0.25):
  for j in range(1,10):
    print(f"DBSCAN with eps: {i}, and min Points: {j}")
    
    dbscan_cluster = DBSCAN(eps=i, min_samples=j, metric='euclidean')

    clusters = dbscan_cluster.fit_predict(X_std)

    print("DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): {}"
        .format(metrics.adjusted_rand_score(y, clusters)))
# Out:
# DBSCAN with eps: 0.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 8.68128597420814e-05
# DBSCAN with eps: 0.5, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0036744082404421437
# DBSCAN with eps: 0.5, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.5, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.5, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.5, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.5, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.5, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.5, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00013021930957340477
# DBSCAN with eps: 0.75, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.00524890185583441
# DBSCAN with eps: 0.75, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.75, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.75, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.75, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.75, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.75, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 0.75, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.0, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0004340648309851829
# DBSCAN with eps: 1.0, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.008961679875102968
# DBSCAN with eps: 1.0, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.002755933782262106
# DBSCAN with eps: 1.0, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.0, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.0, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.0, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.0, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.0, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.25, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0034691953611277575
# DBSCAN with eps: 1.25, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.007185207833924711
# DBSCAN with eps: 1.25, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.006085744183564509
# DBSCAN with eps: 1.25, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.000805260449603288
# DBSCAN with eps: 1.25, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.003408841616985725
# DBSCAN with eps: 1.25, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.003408841616985725
# DBSCAN with eps: 1.25, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.25, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.25, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 1.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.007935993562794265
# DBSCAN with eps: 1.5, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00017005545713447604
# DBSCAN with eps: 1.5, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0025585462533620116
# DBSCAN with eps: 1.5, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0029501548839165888
# DBSCAN with eps: 1.5, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.003995087065128448
# DBSCAN with eps: 1.5, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.005825209251207574
# DBSCAN with eps: 1.5, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.005825209251207574
# DBSCAN with eps: 1.5, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.006170026016997721
# DBSCAN with eps: 1.5, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.006037806037788789
# DBSCAN with eps: 1.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01368836573290993
# DBSCAN with eps: 1.75, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.010790529728726482
# DBSCAN with eps: 1.75, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.007368594643298251
# DBSCAN with eps: 1.75, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0048442567039770614
# DBSCAN with eps: 1.75, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0030411269833782854
# DBSCAN with eps: 1.75, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00022512456868557231
# DBSCAN with eps: 1.75, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0015416475887957879
# DBSCAN with eps: 1.75, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.004568643889380751
# DBSCAN with eps: 1.75, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.004568643889380751
# DBSCAN with eps: 2.0, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.021441604491943305
# DBSCAN with eps: 2.0, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.019719752281555758
# DBSCAN with eps: 2.0, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.023475936862224274
# DBSCAN with eps: 2.0, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.018230172604469602
# DBSCAN with eps: 2.0, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.014409669379190203
# DBSCAN with eps: 2.0, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.014947738155427494
# DBSCAN with eps: 2.0, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01351485426859467
# DBSCAN with eps: 2.0, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0034433234926160208
# DBSCAN with eps: 2.0, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00573430990027919
# DBSCAN with eps: 2.25, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.08072698143984362
# DBSCAN with eps: 2.25, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.08062250952008125
# DBSCAN with eps: 2.25, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.07958736704172593
# DBSCAN with eps: 2.25, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.11014002566826875
# DBSCAN with eps: 2.25, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0974335247501563
# DBSCAN with eps: 2.25, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.11374093912422496
# DBSCAN with eps: 2.25, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.08972289619647869
# DBSCAN with eps: 2.25, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.043929476386970326
# DBSCAN with eps: 2.25, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.037992944383035805
# DBSCAN with eps: 2.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.02761084266040348
# DBSCAN with eps: 2.5, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.02980798801119356
# DBSCAN with eps: 2.5, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.026364965303203362
# DBSCAN with eps: 2.5, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.04256684006255322
# DBSCAN with eps: 2.5, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.03194943501226216
# DBSCAN with eps: 2.5, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.027249046523624868
# DBSCAN with eps: 2.5, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.034700786022760284
# DBSCAN with eps: 2.5, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.15185393743640385
# DBSCAN with eps: 2.5, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.13782299361644157
# DBSCAN with eps: 2.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.020851684467945303
# DBSCAN with eps: 2.75, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.02665967416418647
# DBSCAN with eps: 2.75, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.02482895174603948
# DBSCAN with eps: 2.75, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.024506919325924973
# DBSCAN with eps: 2.75, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.02437858268108625
# DBSCAN with eps: 2.75, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.022212359400087024
# DBSCAN with eps: 2.75, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.026793894625208554
# DBSCAN with eps: 2.75, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.029246975278069673
# DBSCAN with eps: 2.75, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.02928133594244194
# DBSCAN with eps: 3.0, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01717734452910878
# DBSCAN with eps: 3.0, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01874696454366683
# DBSCAN with eps: 3.0, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.02064668894650054
# DBSCAN with eps: 3.0, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01878431376471715
# DBSCAN with eps: 3.0, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.017058674035030252
# DBSCAN with eps: 3.0, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01385902314509333
# DBSCAN with eps: 3.0, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.010650198617115554
# DBSCAN with eps: 3.0, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.009099657473989692
# DBSCAN with eps: 3.0, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.012385964877585188
# DBSCAN with eps: 3.25, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.011812870097277906
# DBSCAN with eps: 3.25, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01161684494528793
# DBSCAN with eps: 3.25, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.011874613338560306
# DBSCAN with eps: 3.25, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.014403197170242625
# DBSCAN with eps: 3.25, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.020641174252270023
# DBSCAN with eps: 3.25, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01652107876261525
# DBSCAN with eps: 3.25, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.015056625259993194
# DBSCAN with eps: 3.25, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.023546452098527633
# DBSCAN with eps: 3.25, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.023546452098527633
# DBSCAN with eps: 3.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.012693232823408757
# DBSCAN with eps: 3.5, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.012864334070508663
# DBSCAN with eps: 3.5, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01321263046561601
# DBSCAN with eps: 3.5, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.013997216334541231
# DBSCAN with eps: 3.5, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01219791988284384
# DBSCAN with eps: 3.5, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01408087269523953
# DBSCAN with eps: 3.5, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.01408087269523953
# DBSCAN with eps: 3.5, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.010568873737546529
# DBSCAN with eps: 3.5, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.010568873737546529
# DBSCAN with eps: 3.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.005276346222230343
# DBSCAN with eps: 3.75, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.005232030478627815
# DBSCAN with eps: 3.75, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.005232030478627815
# DBSCAN with eps: 3.75, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0053622146908550595
# DBSCAN with eps: 3.75, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0053622146908550595
# DBSCAN with eps: 3.75, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00689773898295227
# DBSCAN with eps: 3.75, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00689773898295227
# DBSCAN with eps: 3.75, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00689773898295227
# DBSCAN with eps: 3.75, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.00689773898295227
# DBSCAN with eps: 4.0, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0001369364398033298
# DBSCAN with eps: 4.0, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 9.291884165881406e-05
# DBSCAN with eps: 4.0, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 9.291884165881406e-05
# DBSCAN with eps: 4.0, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 9.291884165881406e-05
# DBSCAN with eps: 4.0, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 9.291884165881406e-05
# DBSCAN with eps: 4.0, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 9.291884165881406e-05
# DBSCAN with eps: 4.0, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 9.291884165881406e-05
# DBSCAN with eps: 4.0, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0025529853418756712
# DBSCAN with eps: 4.0, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0025529853418756712
# DBSCAN with eps: 4.25, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.25, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.25, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.25, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.25, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.25, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.25, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.25, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.25, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): -0.0010061512759301108
# DBSCAN with eps: 4.5, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.5, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.5, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.5, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.5, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.5, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.5, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.5, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.5, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 1
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 2
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 3
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 4
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 5
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 6
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 7
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 8
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0
# DBSCAN with eps: 4.75, and min Points: 9
# DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.0

# %%
""" we got the best score for these values;
DBSCAN with eps: 2.25, and min Points: 6
DBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.11374093912422496
"""
# Out:
# ' we got the best score for these values;\nDBSCAN with eps: 2.25, and min Points: 6\nDBSCAN çözümünün Düzeltilmiş Rand Endeksi (ARI): 0.11374093912422496\n'

# %%
# so I'll try to get the silh. score of that 
dbscan_cluster = DBSCAN(eps=2.25, min_samples=6, metric='euclidean')
clusters = dbscan_cluster.fit_predict(X_std)

print("DBSCAN çözümünün siluet skoru: {}"
      .format(metrics.silhouette_score(X_std, clusters, metric='euclidean')))
# Out:
# DBSCAN çözümünün siluet skoru: -0.047508700429683956

# %%
# It didn't turned out to be the best silhouette score.
